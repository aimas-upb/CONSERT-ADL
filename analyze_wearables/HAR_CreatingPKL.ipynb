# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2a886060-c443-464a-91be-d955107103f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a886060-c443-464a-91be-d955107103f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv
# Saving train.csv to train.csv

# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
print('Number of duplicates in train : ',sum(train.duplicated()))
print('Number of duplicates in test : ', sum(test.duplicated()))
# Out:
# Number of duplicates in train :  0
# Number of duplicates in test :  0

# %%
print('Total number of missing values in train : ', train.isna().values.sum())
print('Total number of missing values in train : ', test.isna().values.sum())
# Out:
# Total number of missing values in train :  0
# Total number of missing values in train :  0

# %%
plt.figure(figsize=(10,8))
plt.title('Barplot of Activity')
sns.countplot(train.Activity)
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ebf512bfe553> in <module>()
# ----> 1 plt.figure(figsize=(10,8))
#       2 plt.title('Barplot of Activity')
#       3 sns.countplot(train.Activity)
#       4 plt.xticks(rotation=90)
#
# NameError: name 'plt' is not defined

# %%
display(train)
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  subject          Activity
# 0              0.288585          -0.020294  ...        1          STANDING
# 1              0.278419          -0.016411  ...        1          STANDING
# 2              0.279653          -0.019467  ...        1          STANDING
# 3              0.279174          -0.026201  ...        1          STANDING
# 4              0.276629          -0.016570  ...        1          STANDING
# ...                 ...                ...  ...      ...               ...
# 7347           0.299665          -0.057193  ...       30  WALKING_UPSTAIRS
# 7348           0.273853          -0.007749  ...       30  WALKING_UPSTAIRS
# 7349           0.273387          -0.017011  ...       30  WALKING_UPSTAIRS
# 7350           0.289654          -0.018843  ...       30  WALKING_UPSTAIRS
# 7351           0.351503          -0.012423  ...       30  WALKING_UPSTAIRS
#
# [7352 rows x 563 columns]

# %%
display(test)

# %%
train.to_pickle("train.pkl")
test.to_pickle("test.pkl")

# %%
train_from_pickle = pd.read_pickle("train.pkl")
test_from_pickle = pd.read_pickle("test.pkl")

display(train_from_pickle)
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  subject          Activity
# 0              0.288585          -0.020294  ...        1          STANDING
# 1              0.278419          -0.016411  ...        1          STANDING
# 2              0.279653          -0.019467  ...        1          STANDING
# 3              0.279174          -0.026201  ...        1          STANDING
# 4              0.276629          -0.016570  ...        1          STANDING
# ...                 ...                ...  ...      ...               ...
# 7347           0.299665          -0.057193  ...       30  WALKING_UPSTAIRS
# 7348           0.273853          -0.007749  ...       30  WALKING_UPSTAIRS
# 7349           0.273387          -0.017011  ...       30  WALKING_UPSTAIRS
# 7350           0.289654          -0.018843  ...       30  WALKING_UPSTAIRS
# 7351           0.351503          -0.012423  ...       30  WALKING_UPSTAIRS
#
# [7352 rows x 563 columns]
